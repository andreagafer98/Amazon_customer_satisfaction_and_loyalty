# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
from nltk.corpus import stopwords
import nltk
import string
import re
from nltk.tokenize import word_tokenize

# %%
with open('/Users/andreagarcia/Desktop/qual.txt', 'r', encoding='utf-8') as file:
    file_content = file.read()

# %%
amazon_mask = np.array(Image.open('/Users/andreagarcia/Desktop/amazon.png'))

# %%
def text_lowercase(file_content):
    return text.lower()

# %%
# removing punctuation
def remove_punctuation(file_content):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

# %%
# removing whitespace from text
def remove_whitespace(ile_content):
    return  " ".join(text.split())

# %%
def remove_stopwords(file_content):
    stop_words = set(stopwords.words("english"))
    word_tokens = word_tokenize(file_content)
    filtered_text = [word for word in word_tokens if word not in stop_words]
    return filtered_text

# %%
#WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='black', colormap = 'copper').generate(file_content)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Preparing Amazon wordcloud
wc = WordCloud(background_color = 'white', mask = amazon_mask, contour_width = 2,
     contour_color = 'white', colormap = 'copper').generate(file_content)
plt.figure(figsize=(15, 10))
plt.axis('off')
plt.imshow(wc)

# %%
from collections import Counter

# %%
words = re.findall(r'\b\w+\b', file_content.lower())
stop_words = set(stopwords.words('english'))

# %%
# Filter out stopwords from the list of words
filtered_words = [word for word in words if word not in stop_words]

# %%
# Count the frequency of each word
word_counts = Counter(filtered_words)

# %%
# Find the most common words (change the number to get more or fewer words)
most_common_words = word_counts.most_common(20)

# %%
# Print the most common words and their frequencies
for word, count in most_common_words:
    print(f'{word}: {count} times')
# Out:
# like: 61 times
# think: 27 times
# amazon: 17 times
# something: 15 times
# people: 9 times
# get: 9 times
# everything: 9 times
# fast: 8 times
# also: 8 times
# obviously: 7 times
# prime: 7 times
# even: 7 times
# always: 7 times
# got: 7 times
# buy: 7 times
# mean: 6 times
# makes: 6 times
# know: 6 times
# one: 6 times
# really: 6 times
